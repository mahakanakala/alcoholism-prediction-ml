# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./data/3D_Data_Array.xlsx')

df.head(30)
# Out:
#    Unnamed: 0                                     Alcohol Intake Unnamed: 2  \
# 0     Mouse #                                              Day 1      Day 2
# 1           1                                             0.3298     0.3293
# 2           2                                             0.3635     0.3518
# 3           3                                             0.1561     0.1554
# 4           4                                             0.6303     0.6085
# 5           5                                             0.2005     0.1987
# 6           6                                             0.2531     0.2669
# 7           7                                             0.7203     0.7171
# 8           8                                             0.8021     0.7895
# 9           9                                             0.3449     0.3346
# 10         10                                             0.3342     0.3281
# ...

# %% [markdown]
# ## Rename cells that are unnamed with the types

# %%
df.columns = [' ',
              'Alcohol Intake', 'Alcohol Intake', 'Alcohol Intake', 
              'Food Intake', 'Food Intake', 'Food Intake', 
              'Water Intake', 'Water Intake', 'Water Intake',
              'Body Weight', 'Body Weight', 'Body Weight']

df.head()
# Out:
#            Alcohol Intake Alcohol Intake Alcohol Intake Food Intake  \
# 0  Mouse #          Day 1          Day 2          Day 3       Day 1
# 1        1         0.3298         0.3293         0.3498      0.3136
# 2        2         0.3635         0.3518         0.3655       0.356
# 3        3         0.1561         0.1554         0.1833      0.1487
# 4        4         0.6303         0.6085         0.6118      0.6438
#
#   Food Intake Food Intake Water Intake Water Intake Water Intake Body Weight  \
# 0       Day 2       Day 3        Day 1        Day 2        Day 3       Day 1
# 1       0.316       0.318       0.3821        0.382       0.4549      0.3125
# 2      0.3553      0.3538       0.5159       0.4694       0.5169      0.4164
# 3      0.1454      0.1489       0.5254       0.3311       0.3439      0.4339
# 4      0.6408      0.6374       0.6123       0.4698       0.3635      0.5215
#
#   Body Weight Body Weight
# 0       Day 2       Day 3
# 1      0.3205       0.376
# ...

# %% [markdown]
# ## Remove Mouse # duplicate Column

# %%
# df.drop(['Mouse #'], axis=1) 

df.head(20)
# Out:
#                                                 Alcohol Intake Alcohol Intake  \
# 0   Mouse #                                              Day 1          Day 2
# 1         1                                             0.3298         0.3293
# 2         2                                             0.3635         0.3518
# 3         3                                             0.1561         0.1554
# 4         4                                             0.6303         0.6085
# 5         5                                             0.2005         0.1987
# 6         6                                             0.2531         0.2669
# 7         7                                             0.7203         0.7171
# 8         8                                             0.8021         0.7895
# 9         9                                             0.3449         0.3346
# 10       10                                             0.3342         0.3281
# ...

# %% [markdown]
# ## Remove extra cells and comment in row 17

# %%
df = df.drop(index=[15,16,17])

# %%
df.to_excel('./data/3D_Data_Array_Processed.xlsx', index=False)
